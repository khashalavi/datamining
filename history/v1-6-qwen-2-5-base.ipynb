# %%
# !pip install bitsandbytes -q
# !pip install --upgrade transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 107.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Collecting transformers
#   Downloading transformers-5.12.1-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.10.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Downloading transformers-5.12.1-py3-none-any.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 105.2 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed transformers-5.12.1

# %%
# %%writefile train_snli_ddp.py
import os
import math
import json
import copy
import random
import time
import numpy as np
import pandas as pd 
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter
from datasets import load_dataset
from torch.utils.data import DataLoader
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    get_cosine_schedule_with_warmup,
    set_seed,
)
from peft import LoraConfig, get_peft_model, TaskType, load_peft_weights, set_peft_model_state_dict

# Scikit-learn is ONLY used at the very end for the final confusion matrix
from sklearn.metrics import confusion_matrix, classification_report

# DDP and High-Speed Metrics
from accelerate import Accelerator
from accelerate.utils import DistributedDataParallelKwargs
import torchmetrics

os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# Seed only the CPU globally. Accelerate handles GPU seeding natively.
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
set_seed(SEED)

def print_gpu_mem(accelerator):
    if torch.cuda.is_available() and accelerator.is_main_process:
        for i in range(torch.cuda.device_count()):
            alloc = torch.cuda.memory_allocated(i) / 1024**3
            reserved = torch.cuda.memory_reserved(i) / 1024**3
            print(f"GPU {i}: allocated={alloc:.2f} GB | reserved={reserved:.2f} GB", flush=True)

# ============================================================
# SECTION 2: Configuration 
# ============================================================
DEBUG_MODE = False # Set False for full 50k-step run

MAX_TRAINING_TIME_SEC = 2000 if DEBUG_MODE else 42000 # Graceful timeout limit (approx 11.1 hours)

MODEL_NAME   =  "Qwen/Qwen3.5-0.8B-Base"
DATASET_NAME = "stanfordnlp/snli"
NUM_LABELS = 3
LABEL2ID   = {"entailment": 0, "neutral": 1, "contradiction": 2}
ID2LABEL   = {0: "entailment", 1: "neutral", 2: "contradiction"}

# Debug Slices
DEBUG_TRAIN_SIZE = 10000
DEBUG_VAL_SIZE   = 1000
DEBUG_TEST_SIZE  = 1000

# Architecture & Hardware
MAX_LENGTH          = 64   
BATCH_SIZE          = 32     # Per GPU (Effective = 256)
GRAD_ACCUM_STEPS    = 2
LEARNING_RATE       = 2e-4    
WEIGHT_DECAY        = 0.01

LORA_R              = 64 
LORA_ALPHA          = 128
LORA_DROPOUT        = 0.05
LORA_TARGET_MODULES = ["q_proj", "k_proj", "v_proj", "o_proj"]

# Step-Based Targets
MAX_STEPS           = 120 if DEBUG_MODE else 18000 
PRINT_EVERY         = 20
EVAL_EVERY          = 40 if DEBUG_MODE else 300
OUTPUT_DIR       = "/kaggle/working/qwen25_snli_ddp_output"
WEIGHTS_DIR      = f"{OUTPUT_DIR}/best_model"
METRICS_FILE     = f"{OUTPUT_DIR}/metrics_log.txt"
LAST_WEIGHTS_DIR = f"{OUTPUT_DIR}/last_model"

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(WEIGHTS_DIR, exist_ok=True)
os.makedirs(LAST_WEIGHTS_DIR, exist_ok=True)

# ============================================================
# MAIN MULTI-GPU TRAINING LOOP
# ============================================================
def main_training_loop():
    
    # Fix for Unused Parameters in Qwen sequence classification
    ddp_kwargs = DistributedDataParallelKwargs(find_unused_parameters=True)
    
    accelerator = Accelerator(
        gradient_accumulation_steps=GRAD_ACCUM_STEPS,
        kwargs_handlers=[ddp_kwargs],
    )
    
    accelerator.print(f"PyTorch : {torch.__version__}")
    accelerator.print(f"GPUs active: {accelerator.num_processes}")

    # ============================================================
    # SECTION 3: Dataset Loading & Tokenization
    # ============================================================
    with accelerator.main_process_first():
        accelerator.print(f"\nLoading SNLI and Tokenizer (MAX_LENGTH={MAX_LENGTH})...")
        raw_dataset = load_dataset(DATASET_NAME)
        raw_dataset = raw_dataset.filter(lambda x: x["label"] != -1)

        if DEBUG_MODE:
            accelerator.print(f"\n>>> DEBUG MODE ACTIVE: Truncating dataset for fast {MAX_STEPS}-step test <<<")
            raw_dataset["train"] = raw_dataset["train"].shuffle(seed=SEED).select(range(min(DEBUG_TRAIN_SIZE, len(raw_dataset["train"]))))
            raw_dataset["validation"] = raw_dataset["validation"].shuffle(seed=SEED).select(range(min(DEBUG_VAL_SIZE, len(raw_dataset["validation"]))))
            raw_dataset["test"] = raw_dataset["test"].shuffle(seed=SEED).select(range(min(DEBUG_TEST_SIZE, len(raw_dataset["test"]))))

        tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, trust_remote_code=True, padding_side="left")
        if tokenizer.pad_token is None:
            tokenizer.pad_token = tokenizer.eos_token
            tokenizer.pad_token_id = tokenizer.eos_token_id

        def preprocess_function(examples):
            texts = [f"Premise: {p}\nHypothesis: {h}\nRelationship:" for p, h in zip(examples["premise"], examples["hypothesis"])]
            tokenized = tokenizer(texts, truncation=True, max_length=MAX_LENGTH, padding=False)
            tokenized["labels"] = examples["label"]
            return tokenized

        tokenized_datasets = raw_dataset.map(preprocess_function, batched=True, remove_columns=["premise", "hypothesis", "label"])
        tokenized_datasets.set_format("torch")

    data_collator = DataCollatorWithPadding(tokenizer=tokenizer, pad_to_multiple_of=8)
    
    # --- SMART BATCHING IMPLEMENTATION ---
    class SmartLengthSampler(torch.utils.data.Sampler):
        def __init__(self, dataset, global_batch_size):
            self.dataset = dataset
            self.global_batch_size = global_batch_size
            self.lengths = [len(x) for x in dataset["input_ids"]]

        def __iter__(self):
            noisy_lengths = np.array(self.lengths) + np.random.uniform(-2, 2, len(self.lengths))
            indices = np.argsort(noisy_lengths)
            batches = [indices[i : i + self.global_batch_size] for i in range(0, len(indices), self.global_batch_size)]
            np.random.shuffle(batches)
            flattened = [idx for batch in batches for idx in batch]
            return iter(flattened)

        def __len__(self):
            return len(self.dataset)

    global_batch_size = BATCH_SIZE * accelerator.num_processes
    train_sampler = SmartLengthSampler(tokenized_datasets["train"], global_batch_size)
    
    train_loader = DataLoader(tokenized_datasets["train"], batch_size=BATCH_SIZE, sampler=train_sampler, collate_fn=data_collator, num_workers=2, prefetch_factor=2, pin_memory=True)
    val_loader = DataLoader(tokenized_datasets["validation"], batch_size=BATCH_SIZE, shuffle=False, collate_fn=data_collator, num_workers=2, prefetch_factor=2, pin_memory=True)
    test_loader = DataLoader(tokenized_datasets["test"], batch_size=BATCH_SIZE, shuffle=False, collate_fn=data_collator, num_workers=2,prefetch_factor=2, pin_memory=True)

    # ============================================================
    # SECTION 4: Model + LoRA
    # ============================================================
    accelerator.print("\nLoading base model...")
    base_model = AutoModelForSequenceClassification.from_pretrained(
        MODEL_NAME, num_labels=NUM_LABELS, id2label=ID2LABEL, label2id=LABEL2ID,
        trust_remote_code=True, ignore_mismatched_sizes=True, attn_implementation="sdpa"
    )
    base_model.config.pad_token_id = tokenizer.pad_token_id
    base_model.config.use_cache = False

    accelerator.print("\n---> Initializing FRESH LoRA weights <---")
    lora_config = LoraConfig(
        r=LORA_R, lora_alpha=LORA_ALPHA, target_modules=LORA_TARGET_MODULES,
        lora_dropout=LORA_DROPOUT, bias="none", task_type=TaskType.SEQ_CLS,
    )
    model = get_peft_model(base_model, lora_config)

    # adding token id for qwen 3.5
    
    model.config.get_text_config().pad_token_id = tokenizer.pad_token_id
    if hasattr(model, "base_model") and hasattr(model.base_model, "model"):
        model.base_model.model.config.get_text_config().pad_token_id = tokenizer.pad_token_id
    
    for name, param in model.named_parameters():
        if "score" in name or "classifier" in name:
            param.requires_grad = True

    for name, module in model.named_modules():
        if isinstance(module, nn.Linear) and ("score" in name or "classifier" in name):
            nn.init.normal_(module.weight, std=0.02)
            if module.bias is not None:
                nn.init.zeros_(module.bias)
            break

    # BUG 6 FIX: Ensure Step 0 weights are saved so we never load 'None' silently
    accelerator.wait_for_everyone()
    if accelerator.is_main_process:
        accelerator.unwrap_model(model).save_pretrained(WEIGHTS_DIR)
        tokenizer.save_pretrained(WEIGHTS_DIR)
    accelerator.wait_for_everyone()

    # ============================================================
    # SECTION 5: Optimizer and Scheduler
    # ============================================================
    optimizer = torch.optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

    warmup_steps = max(1, int(0.05 * MAX_STEPS))
    scheduler_steps = int(MAX_STEPS * 1.2)
    scheduler = get_cosine_schedule_with_warmup(optimizer, num_warmup_steps=warmup_steps, num_training_steps=scheduler_steps)
    
    train_criterion = nn.CrossEntropyLoss()
    # BUG 4 FIX: Unreduced loss to gather exact samples without DDP padding artifacts
    eval_criterion = nn.CrossEntropyLoss(reduction="none")

    model, optimizer, train_dl, val_dl, test_dl, scheduler = accelerator.prepare(
        model, optimizer, train_loader, val_loader, test_loader, scheduler
    )

    accuracy_metric = torchmetrics.Accuracy(task="multiclass", num_classes=NUM_LABELS).to(accelerator.device)
    f1_metric = torchmetrics.F1Score(task="multiclass", num_classes=NUM_LABELS, average="macro").to(accelerator.device)

    # ============================================================
    # SECTION 6: High-Speed GPU Evaluation Function
    # ============================================================
    @torch.no_grad()
    def evaluate(model, dataloader, split_name="Validation", return_preds=False):
        model.eval()
        total_loss, total_samples = 0.0, 0
        
        if return_preds:
            all_preds, all_labels = [], []

        for batch in dataloader:
            outputs = model(input_ids=batch["input_ids"], attention_mask=batch["attention_mask"])
            
            loss = eval_criterion(outputs.logits.float(), batch["labels"].long())
            preds = torch.argmax(outputs.logits, dim=-1)

            # BUG 2 & 4 FIX: Gather precise metrics/losses, auto-dropping DDP dummy padding duplicates
            loss_gathered = accelerator.gather_for_metrics(loss)
            preds_gathered, labels_gathered = accelerator.gather_for_metrics((preds, batch["labels"]))
            
            total_loss += loss_gathered.sum().item()
            total_samples += loss_gathered.numel()

            accuracy_metric.update(preds_gathered, labels_gathered)
            f1_metric.update(preds_gathered, labels_gathered)

            if return_preds:
                all_preds.extend(preds_gathered.cpu().numpy().tolist())
                all_labels.extend(labels_gathered.cpu().numpy().tolist())

        acc = accuracy_metric.compute().item()
        f1 = f1_metric.compute().item()
        avg_loss = total_loss / max(1, total_samples)

        accuracy_metric.reset()
        f1_metric.reset()

        accelerator.print(f"[{split_name}] loss={avg_loss:.4f} | acc={acc:.4f} | f1={f1:.4f}")
        
        if return_preds:
            return {"loss": avg_loss, "accuracy": acc, "f1_macro": f1}, all_preds, all_labels
        else:
            return {"loss": avg_loss, "accuracy": acc, "f1_macro": f1}

    # ============================================================
    # SECTION 7: Pure Step-Based Training Loop
    # ============================================================
    best_val_acc, best_step = -1.0, 0
    train_loss_history, val_acc_history, val_loss_history, step_history = [], [], [], []
    
    global_step = 0
    current_train_loss = 0.0

    if accelerator.is_main_process:
        with open(METRICS_FILE, "w") as f:
            f.write(f"\nModel: {MODEL_NAME}\nDataset: {DATASET_NAME}\n\n")

    accelerator.print(f"\nStarting Fast DDP Training (Target: {MAX_STEPS} steps)...")
    
    def get_infinite_batches(dl):
        while True:
            for b in dl:
                yield b
                
    train_iterator = get_infinite_batches(train_dl)
    model.train()
    start_time = time.time()

    while global_step < MAX_STEPS:
        
        batch = next(train_iterator)

        with accelerator.accumulate(model):
            outputs = model(input_ids=batch["input_ids"], attention_mask=batch["attention_mask"])
            loss = train_criterion(outputs.logits.float(), batch["labels"].long())
            
            accelerator.backward(loss)
            if accelerator.sync_gradients:
                accelerator.clip_grad_norm_(model.parameters(), 1.0)
            
            optimizer.step()
            scheduler.step()
            optimizer.zero_grad(set_to_none=True)

        # BUG 3 FIX: Accurately collect training loss across all DDP GPUs
        gathered_loss = accelerator.reduce(loss.detach(), reduction="mean")
        
        # BUG 7 FIX: Use EMA loss. Automatically averts the 0.0 print bug and smooths graph data
        if current_train_loss == 0.0:
            current_train_loss = gathered_loss.item()
        else:
            current_train_loss = 0.95 * current_train_loss + 0.05 * gathered_loss.item()

        if accelerator.sync_gradients:
            global_step += 1
       
            current_time = time.time() - start_time
            is_timeout = 1 if current_time > MAX_TRAINING_TIME_SEC else 0
            timeout_tensor = torch.tensor([is_timeout], dtype=torch.int, device=accelerator.device)
            timeout_gathered = accelerator.gather(timeout_tensor)
            
            if timeout_gathered.sum().item() > 0:
                accelerator.print(f"\n*** GRACEFUL TIMEOUT: Time limit reached. Stopping training at step {global_step} to save weights. ***\n")
                break
                       
            if global_step % PRINT_EVERY == 0:
                if accelerator.is_main_process:
                    accelerator.print(f"[Step {global_step}/{MAX_STEPS}] Train Loss (EMA): {current_train_loss:.4f} | LR: {scheduler.get_last_lr()[0]:.2e}")

            if global_step % EVAL_EVERY == 0:
                accelerator.print(f"\n--- Full Evaluation at Step {global_step} ---")
                
                val_metrics = evaluate(model, val_dl, split_name=f"Val-Step-{global_step}", return_preds=False)
                model.train() 
                
                if accelerator.is_main_process:
                    print_gpu_mem(accelerator)
                    train_loss_history.append(current_train_loss)
                    step_history.append(global_step)
                    val_acc_history.append(val_metrics["accuracy"])
                    val_loss_history.append(val_metrics["loss"])

                    with open(METRICS_FILE, "a") as f:
                        f.write(f"Step {global_step} / {MAX_STEPS}\n")
                        f.write(f"train_loss_ema: {current_train_loss:.6f}\n")
                        f.write(f"val_loss: {val_metrics['loss']:.6f}\n")
                        f.write(f"val_accuracy: {val_metrics['accuracy']:.6f}\n\n")
                
                if val_metrics["accuracy"] > best_val_acc:
                    best_val_acc = val_metrics["accuracy"]
                    best_step = global_step
                    
                    # BUG 5 FIX: Eliminate DDP state dictionary memory leak. Save direct to disk ONLY on Main Node.
                    accelerator.wait_for_everyone()
                    if accelerator.is_main_process:
                        accelerator.unwrap_model(model).save_pretrained(WEIGHTS_DIR)
                        tokenizer.save_pretrained(WEIGHTS_DIR)
                        accelerator.print(f"[save] Intermediate model saved at step {best_step} with val_acc={best_val_acc:.4f}\n")
                    accelerator.wait_for_everyone()

    accelerator.wait_for_everyone()
    
    # ============================================================
    # SECTION 8: Final Saving & Plotting 
    # ============================================================
    if accelerator.is_main_process:
        accelerator.print("\nSaving the final (last) step model...")
        
        unwrapped_model = accelerator.unwrap_model(model)
        unwrapped_model.save_pretrained(LAST_WEIGHTS_DIR)
        tokenizer.save_pretrained(LAST_WEIGHTS_DIR)

        accelerator.print("\nGenerating training curves...")
        plt.figure(figsize=(12, 4))
        plt.subplot(1, 2, 1)
        plt.plot(step_history, train_loss_history, marker="o", label="Train Loss (EMA)")
        plt.plot(step_history, val_loss_history, marker="o", color="darkorange", label="Val Loss")
        plt.title("Loss Curves"); plt.xlabel("Global Step"); plt.legend(); plt.grid(alpha=0.3)
        plt.subplot(1, 2, 2)
        plt.plot(step_history, val_acc_history, marker="o", color="green", label="Val Accuracy")
        plt.title("Validation Accuracy"); plt.xlabel("Global Step"); plt.legend(); plt.grid(alpha=0.3)
        plt.savefig(f"{OUTPUT_DIR}/training_curves.png", dpi=150)
        plt.close()

    # ============================================================
    # SECTION 9: Final Test Evaluation & Error Extraction
    # ============================================================
    label_names = [ID2LABEL[i] for i in range(NUM_LABELS)]
    
    accelerator.print("\n=== Evaluating LAST Step Model ===")
    last_metrics, last_preds, last_labels = evaluate(model, test_dl, split_name="Test-Last", return_preds=True)
    
    accelerator.print("\n=== Restoring and Evaluating BEST Step Model ===")
    accelerator.wait_for_everyone()
    
    # BUG 5 & 6 FIX: All DDP GPUs load directly from the synced disk safely
    unwrapped_model = accelerator.unwrap_model(model)
    adapters_weights = load_peft_weights(WEIGHTS_DIR)
    set_peft_model_state_dict(unwrapped_model, adapters_weights)
    
    best_metrics, best_preds, best_labels = evaluate(model, test_dl, split_name="Test-Best", return_preds=True)

    if accelerator.is_main_process:
        last_report = classification_report(last_labels, last_preds, target_names=label_names)
        best_report = classification_report(best_labels, best_preds, target_names=label_names)
        
        with open(METRICS_FILE, "a") as f:
            f.write("\n=== FINAL TEST EVALUATION ===\n--- LAST MODEL REPORT ---\n" + last_report + "\n--- BEST MODEL REPORT ---\n" + best_report + "\n")

        fig, axes = plt.subplots(1, 2, figsize=(12, 5))
        sns.heatmap(confusion_matrix(last_labels, last_preds), annot=True, fmt="d", cmap="Blues", xticklabels=label_names, yticklabels=label_names, ax=axes[0], cbar=False)
        axes[0].set_title("Confusion Matrix: LAST")
        sns.heatmap(confusion_matrix(best_labels, best_preds), annot=True, fmt="d", cmap="Greens", xticklabels=label_names, yticklabels=label_names, ax=axes[1], cbar=False)
        axes[1].set_title("Confusion Matrix: BEST")
        plt.savefig(f"{OUTPUT_DIR}/confusion_matrices_comparison.png", dpi=150)
        plt.close()

        accelerator.print("\nExtracting 'Hard Cases' for Qualitative Error Analysis...")
        
        test_premises = raw_dataset["test"]["premise"]
        test_hypotheses = raw_dataset["test"]["hypothesis"]

        last_failures = []
        best_failures = []
        both_failures = []

        for i in range(len(best_labels)):
            true_label_idx = best_labels[i]
            last_pred_idx = last_preds[i]
            best_pred_idx = best_preds[i]

            failed_last = (last_pred_idx != true_label_idx)
            failed_best = (best_pred_idx != true_label_idx)

            if failed_last or failed_best:
                row = {
                    "Index": i,
                    "Premise": test_premises[i],
                    "Hypothesis": test_hypotheses[i],
                    "True_Label": ID2LABEL[true_label_idx],
                    "Last_Model_Prediction": ID2LABEL[last_pred_idx],
                    "Best_Model_Prediction": ID2LABEL[best_pred_idx]
                }

                if failed_last:
                    last_failures.append(row)
                if failed_best:
                    best_failures.append(row)
                if failed_last and failed_best:
                    both_failures.append(row)

        pd.DataFrame(last_failures).to_csv(f"{OUTPUT_DIR}/failures_last_model.csv", index=False)
        pd.DataFrame(best_failures).to_csv(f"{OUTPUT_DIR}/failures_best_model.csv", index=False)
        pd.DataFrame(both_failures).to_csv(f"{OUTPUT_DIR}/failures_both_models_hard_cases.csv", index=False)

        accelerator.print(f"Saved {len(last_failures)} Last Model failures.")
        accelerator.print(f"Saved {len(best_failures)} Best Model failures.")
        accelerator.print(f"Saved {len(both_failures)} overlapping 'Hard Cases'.")

        print("\nTraining Complete. All files saved to:", OUTPUT_DIR)

    accelerator.end_training()

if __name__ == "__main__":
    main_training_loop()
# Out:
# Writing train_snli_ddp.py

# %%
# !accelerate launch --multi_gpu --num_processes=2 train_snli_ddp.py
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# PyTorch : 2.10.0+cu128
# GPUs active: 2
#
# Loading SNLI and Tokenizer (MAX_LENGTH=64)...
# README.md: 16.0kB [00:00, 33.5MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# plain_text/test-00000-of-00001.parquet: 100%|█| 412k/412k [00:00<00:00, 413kB/s]
# plain_text/validation-00000-of-00001.par(…): 100%|█| 413k/413k [00:00<00:00, 997
# plain_text/train-00000-of-00001.parquet: 100%|█| 19.6M/19.6M [00:00<00:00, 24.1M
# Generating test split: 100%|███| 10000/10000 [00:00<00:00, 136322.55 examples/s]
# Generating validation split: 100%|█| 10000/10000 [00:00<00:00, 1268771.25 exampl
# Generating train split: 100%|█| 550152/550152 [00:00<00:00, 2069637.19 examples/
# Filter: 100%|██████████████████| 10000/10000 [00:00<00:00, 233918.78 examples/s]
# Filter: 100%|██████████████████| 10000/10000 [00:00<00:00, 298682.16 examples/s]
# Filter: 100%|████████████████| 550152/550152 [00:01<00:00, 320894.48 examples/s]
# config.json: 2.91kB [00:00, 6.57MB/s]
# tokenizer_config.json: 16.7kB [00:00, 57.9MB/s]
# vocab.json: 6.72MB [00:00, 96.3MB/s]
# merges.txt: 3.35MB [00:00, 114MB/s]
# tokenizer.json: 100%|██████████████████████| 12.8M/12.8M [00:00<00:00, 31.0MB/s]
# Map: 100%|████████████████████████| 9824/9824 [00:00<00:00, 16866.98 examples/s]
# Map: 100%|████████████████████████| 9842/9842 [00:00<00:00, 17618.38 examples/s]
# Map: 100%|████████████████████| 549367/549367 [00:33<00:00, 16466.59 examples/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Loading base model...
# model.safetensors.index.json: 50.9kB [00:00, 92.5MB/s]
# model.safetensors-00001-of-00001.safeten(…): 100%|█| 1.75G/1.75G [00:07<00:00, 2
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# Loading weights: 100%|██████████████████████| 473/473 [00:00<00:00, 2814.14it/s]
# [transformers] Qwen3_5ForSequenceClassification LOAD REPORT from: Qwen/Qwen3.5-0.8B-Base
# Key          | Status  |
# -------------+---------+-
# score.weight | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#
# ---> Initializing FRESH LoRA weights <---
# [transformers] The fast path is not available because one of the required library is not installed. Falling back to torch implementation. To install follow https://github.com/fla-org/flash-linear-attention#installation and https://github.com/Dao-AILab/causal-conv1d
# Loading weights: 100%|██████████████████████| 473/473 [00:00<00:00, 2522.88it/s]
# [transformers] Qwen3_5ForSequenceClassification LOAD REPORT from: Qwen/Qwen3.5-0.8B-Base
# Key          | Status  |
# -------------+---------+-
# score.weight | MISSING |
#
# Notes:
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
#
# Starting Fast DDP Training (Target: 18000 steps)...
# [transformers] `use_return_dict` is deprecated! Use `return_dict` instead!
# [transformers] `use_return_dict` is deprecated! Use `return_dict` instead!
# [Step 20/18000] Train Loss (EMA): 1.3579 | LR: 8.89e-06
# [Step 40/18000] Train Loss (EMA): 0.9606 | LR: 1.78e-05
# [Step 60/18000] Train Loss (EMA): 0.5888 | LR: 2.67e-05
# [Step 80/18000] Train Loss (EMA): 0.4747 | LR: 3.56e-05
# [Step 100/18000] Train Loss (EMA): 0.4369 | LR: 4.44e-05
# [Step 120/18000] Train Loss (EMA): 0.4307 | LR: 5.33e-05
# [Step 140/18000] Train Loss (EMA): 0.3925 | LR: 6.22e-05
# [Step 160/18000] Train Loss (EMA): 0.4024 | LR: 7.11e-05
# [Step 180/18000] Train Loss (EMA): 0.4058 | LR: 8.00e-05
# [Step 200/18000] Train Loss (EMA): 0.3781 | LR: 8.89e-05
# [Step 220/18000] Train Loss (EMA): 0.3913 | LR: 9.78e-05
# [Step 240/18000] Train Loss (EMA): 0.4224 | LR: 1.07e-04
# [Step 260/18000] Train Loss (EMA): 0.3939 | LR: 1.16e-04
# [Step 280/18000] Train Loss (EMA): 0.3580 | LR: 1.24e-04
# [Step 300/18000] Train Loss (EMA): 0.3783 | LR: 1.33e-04
#
# --- Full Evaluation at Step 300 ---
# /usr/local/lib/python3.12/dist-packages/torch/distributed/c10d_logger.py:83: UserWarning: barrier(): using the device under current context. You can specify `device_id` in `init_process_group` to mute this warning.
#   return func(*args, **kwargs)
# [Val-Step-300] loss=0.3298 | acc=0.8810 | f1=0.8812
# GPU 0: allocated=3.20 GB | reserved=13.25 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 300 with val_acc=0.8810
#
# [Step 320/18000] Train Loss (EMA): 0.3513 | LR: 1.42e-04
# [Step 340/18000] Train Loss (EMA): 0.3598 | LR: 1.51e-04
# [Step 360/18000] Train Loss (EMA): 0.3807 | LR: 1.60e-04
# [Step 380/18000] Train Loss (EMA): 0.4026 | LR: 1.69e-04
# [Step 400/18000] Train Loss (EMA): 0.3714 | LR: 1.78e-04
# [Step 420/18000] Train Loss (EMA): 0.3702 | LR: 1.87e-04
# [Step 440/18000] Train Loss (EMA): 0.3629 | LR: 1.96e-04
# [Step 460/18000] Train Loss (EMA): 0.3950 | LR: 2.00e-04
# [Step 480/18000] Train Loss (EMA): 0.3493 | LR: 2.00e-04
# [Step 500/18000] Train Loss (EMA): 0.3833 | LR: 2.00e-04
# [Step 520/18000] Train Loss (EMA): 0.3842 | LR: 2.00e-04
# [Step 540/18000] Train Loss (EMA): 0.3665 | LR: 2.00e-04
# [Step 560/18000] Train Loss (EMA): 0.3551 | LR: 2.00e-04
# [Step 580/18000] Train Loss (EMA): 0.3605 | LR: 2.00e-04
# [Step 600/18000] Train Loss (EMA): 0.3560 | LR: 2.00e-04
#
# --- Full Evaluation at Step 600 ---
# [Val-Step-600] loss=0.2764 | acc=0.8968 | f1=0.8955
# GPU 0: allocated=3.20 GB | reserved=13.25 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 600 with val_acc=0.8968
#
# [Step 620/18000] Train Loss (EMA): 0.3404 | LR: 2.00e-04
# [Step 640/18000] Train Loss (EMA): 0.3382 | LR: 2.00e-04
# [Step 660/18000] Train Loss (EMA): 0.3860 | LR: 2.00e-04
# [Step 680/18000] Train Loss (EMA): 0.3597 | LR: 2.00e-04
# [Step 700/18000] Train Loss (EMA): 0.3877 | LR: 2.00e-04
# [Step 720/18000] Train Loss (EMA): 0.3592 | LR: 2.00e-04
# [Step 740/18000] Train Loss (EMA): 0.3811 | LR: 2.00e-04
# [Step 760/18000] Train Loss (EMA): 0.3429 | LR: 2.00e-04
# [Step 780/18000] Train Loss (EMA): 0.3456 | LR: 1.99e-04
# [Step 800/18000] Train Loss (EMA): 0.3585 | LR: 1.99e-04
# [Step 820/18000] Train Loss (EMA): 0.3398 | LR: 1.99e-04
# [Step 840/18000] Train Loss (EMA): 0.3372 | LR: 1.99e-04
# [Step 860/18000] Train Loss (EMA): 0.3394 | LR: 1.99e-04
# [Step 880/18000] Train Loss (EMA): 0.3106 | LR: 1.99e-04
# [Step 900/18000] Train Loss (EMA): 0.3118 | LR: 1.99e-04
#
# --- Full Evaluation at Step 900 ---
# [Val-Step-900] loss=0.3061 | acc=0.8894 | f1=0.8906
# GPU 0: allocated=3.20 GB | reserved=13.25 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [Step 920/18000] Train Loss (EMA): 0.3570 | LR: 1.99e-04
# [Step 940/18000] Train Loss (EMA): 0.3247 | LR: 1.99e-04
# [Step 960/18000] Train Loss (EMA): 0.3359 | LR: 1.99e-04
# [Step 980/18000] Train Loss (EMA): 0.3194 | LR: 1.99e-04
# [Step 1000/18000] Train Loss (EMA): 0.3299 | LR: 1.99e-04
# [Step 1020/18000] Train Loss (EMA): 0.3691 | LR: 1.99e-04
# [Step 1040/18000] Train Loss (EMA): 0.3225 | LR: 1.98e-04
# [Step 1060/18000] Train Loss (EMA): 0.3177 | LR: 1.98e-04
# [Step 1080/18000] Train Loss (EMA): 0.3234 | LR: 1.98e-04
# [Step 1100/18000] Train Loss (EMA): 0.3325 | LR: 1.98e-04
# [Step 1120/18000] Train Loss (EMA): 0.3125 | LR: 1.98e-04
# [Step 1140/18000] Train Loss (EMA): 0.3436 | LR: 1.98e-04
# [Step 1160/18000] Train Loss (EMA): 0.3653 | LR: 1.98e-04
# [Step 1180/18000] Train Loss (EMA): 0.3532 | LR: 1.98e-04
# [Step 1200/18000] Train Loss (EMA): 0.3461 | LR: 1.97e-04
#
# --- Full Evaluation at Step 1200 ---
# [Val-Step-1200] loss=0.2812 | acc=0.8998 | f1=0.8999
# GPU 0: allocated=3.21 GB | reserved=13.25 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 1200 with val_acc=0.8998
#
# [Step 1220/18000] Train Loss (EMA): 0.3471 | LR: 1.97e-04
# [Step 1240/18000] Train Loss (EMA): 0.3107 | LR: 1.97e-04
# [Step 1260/18000] Train Loss (EMA): 0.3572 | LR: 1.97e-04
# [Step 1280/18000] Train Loss (EMA): 0.3636 | LR: 1.97e-04
# [Step 1300/18000] Train Loss (EMA): 0.3007 | LR: 1.97e-04
# [Step 1320/18000] Train Loss (EMA): 0.3342 | LR: 1.97e-04
# [Step 1340/18000] Train Loss (EMA): 0.3409 | LR: 1.96e-04
# [Step 1360/18000] Train Loss (EMA): 0.3510 | LR: 1.96e-04
# [Step 1380/18000] Train Loss (EMA): 0.3079 | LR: 1.96e-04
# [Step 1400/18000] Train Loss (EMA): 0.2974 | LR: 1.96e-04
# [Step 1420/18000] Train Loss (EMA): 0.3264 | LR: 1.96e-04
# [Step 1440/18000] Train Loss (EMA): 0.3036 | LR: 1.96e-04
# [Step 1460/18000] Train Loss (EMA): 0.3280 | LR: 1.95e-04
# [Step 1480/18000] Train Loss (EMA): 0.3413 | LR: 1.95e-04
# [Step 1500/18000] Train Loss (EMA): 0.3286 | LR: 1.95e-04
#
# --- Full Evaluation at Step 1500 ---
# [Val-Step-1500] loss=0.2767 | acc=0.9027 | f1=0.9022
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 1500 with val_acc=0.9027
#
# [Step 1520/18000] Train Loss (EMA): 0.3316 | LR: 1.95e-04
# [Step 1540/18000] Train Loss (EMA): 0.3360 | LR: 1.95e-04
# [Step 1560/18000] Train Loss (EMA): 0.3099 | LR: 1.94e-04
# [Step 1580/18000] Train Loss (EMA): 0.3287 | LR: 1.94e-04
# [Step 1600/18000] Train Loss (EMA): 0.2867 | LR: 1.94e-04
# [Step 1620/18000] Train Loss (EMA): 0.3050 | LR: 1.94e-04
# [Step 1640/18000] Train Loss (EMA): 0.3308 | LR: 1.94e-04
# [Step 1660/18000] Train Loss (EMA): 0.2964 | LR: 1.93e-04
# [Step 1680/18000] Train Loss (EMA): 0.3182 | LR: 1.93e-04
# [Step 1700/18000] Train Loss (EMA): 0.3159 | LR: 1.93e-04
# [Step 1720/18000] Train Loss (EMA): 0.3119 | LR: 1.93e-04
# [Step 1740/18000] Train Loss (EMA): 0.2928 | LR: 1.92e-04
# [Step 1760/18000] Train Loss (EMA): 0.2983 | LR: 1.92e-04
# [Step 1780/18000] Train Loss (EMA): 0.3255 | LR: 1.92e-04
# [Step 1800/18000] Train Loss (EMA): 0.2966 | LR: 1.92e-04
#
# --- Full Evaluation at Step 1800 ---
# [Val-Step-1800] loss=0.2584 | acc=0.9035 | f1=0.9025
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 1800 with val_acc=0.9035
#
# [Step 1820/18000] Train Loss (EMA): 0.3115 | LR: 1.91e-04
# [Step 1840/18000] Train Loss (EMA): 0.3250 | LR: 1.91e-04
# [Step 1860/18000] Train Loss (EMA): 0.3086 | LR: 1.91e-04
# [Step 1880/18000] Train Loss (EMA): 0.3230 | LR: 1.91e-04
# [Step 1900/18000] Train Loss (EMA): 0.2997 | LR: 1.90e-04
# [Step 1920/18000] Train Loss (EMA): 0.3233 | LR: 1.90e-04
# [Step 1940/18000] Train Loss (EMA): 0.3013 | LR: 1.90e-04
# [Step 1960/18000] Train Loss (EMA): 0.3076 | LR: 1.90e-04
# [Step 1980/18000] Train Loss (EMA): 0.3068 | LR: 1.89e-04
# [Step 2000/18000] Train Loss (EMA): 0.3194 | LR: 1.89e-04
# [Step 2020/18000] Train Loss (EMA): 0.3166 | LR: 1.89e-04
# [Step 2040/18000] Train Loss (EMA): 0.3230 | LR: 1.89e-04
# [Step 2060/18000] Train Loss (EMA): 0.3102 | LR: 1.88e-04
# [Step 2080/18000] Train Loss (EMA): 0.3116 | LR: 1.88e-04
# [Step 2100/18000] Train Loss (EMA): 0.3172 | LR: 1.88e-04
#
# --- Full Evaluation at Step 2100 ---
# [Val-Step-2100] loss=0.2614 | acc=0.9042 | f1=0.9035
# GPU 0: allocated=3.21 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 2100 with val_acc=0.9042
#
# [Step 2120/18000] Train Loss (EMA): 0.2987 | LR: 1.87e-04
# [Step 2140/18000] Train Loss (EMA): 0.2924 | LR: 1.87e-04
# [Step 2160/18000] Train Loss (EMA): 0.2923 | LR: 1.87e-04
# [Step 2180/18000] Train Loss (EMA): 0.2975 | LR: 1.87e-04
# [Step 2200/18000] Train Loss (EMA): 0.2962 | LR: 1.86e-04
# [Step 2220/18000] Train Loss (EMA): 0.3299 | LR: 1.86e-04
# [Step 2240/18000] Train Loss (EMA): 0.3017 | LR: 1.86e-04
# [Step 2260/18000] Train Loss (EMA): 0.3174 | LR: 1.85e-04
# [Step 2280/18000] Train Loss (EMA): 0.3258 | LR: 1.85e-04
# [Step 2300/18000] Train Loss (EMA): 0.3300 | LR: 1.85e-04
# [Step 2320/18000] Train Loss (EMA): 0.3058 | LR: 1.84e-04
# [Step 2340/18000] Train Loss (EMA): 0.2949 | LR: 1.84e-04
# [Step 2360/18000] Train Loss (EMA): 0.3161 | LR: 1.84e-04
# [Step 2380/18000] Train Loss (EMA): 0.3336 | LR: 1.83e-04
# [Step 2400/18000] Train Loss (EMA): 0.3441 | LR: 1.83e-04
#
# --- Full Evaluation at Step 2400 ---
# [Val-Step-2400] loss=0.2427 | acc=0.9118 | f1=0.9116
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 2400 with val_acc=0.9118
#
# [Step 2420/18000] Train Loss (EMA): 0.3330 | LR: 1.83e-04
# [Step 2440/18000] Train Loss (EMA): 0.3117 | LR: 1.82e-04
# [Step 2460/18000] Train Loss (EMA): 0.3233 | LR: 1.82e-04
# [Step 2480/18000] Train Loss (EMA): 0.3022 | LR: 1.82e-04
# [Step 2500/18000] Train Loss (EMA): 0.2924 | LR: 1.81e-04
# [Step 2520/18000] Train Loss (EMA): 0.3141 | LR: 1.81e-04
# [Step 2540/18000] Train Loss (EMA): 0.2915 | LR: 1.81e-04
# [Step 2560/18000] Train Loss (EMA): 0.3180 | LR: 1.80e-04
# [Step 2580/18000] Train Loss (EMA): 0.3009 | LR: 1.80e-04
# [Step 2600/18000] Train Loss (EMA): 0.3236 | LR: 1.79e-04
# [Step 2620/18000] Train Loss (EMA): 0.3228 | LR: 1.79e-04
# [Step 2640/18000] Train Loss (EMA): 0.2868 | LR: 1.79e-04
# [Step 2660/18000] Train Loss (EMA): 0.2946 | LR: 1.78e-04
# [Step 2680/18000] Train Loss (EMA): 0.3120 | LR: 1.78e-04
# [Step 2700/18000] Train Loss (EMA): 0.2981 | LR: 1.78e-04
#
# --- Full Evaluation at Step 2700 ---
# [Val-Step-2700] loss=0.2490 | acc=0.9097 | f1=0.9091
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [Step 2720/18000] Train Loss (EMA): 0.2969 | LR: 1.77e-04
# [Step 2740/18000] Train Loss (EMA): 0.2940 | LR: 1.77e-04
# [Step 2760/18000] Train Loss (EMA): 0.2864 | LR: 1.76e-04
# [Step 2780/18000] Train Loss (EMA): 0.2929 | LR: 1.76e-04
# [Step 2800/18000] Train Loss (EMA): 0.2841 | LR: 1.76e-04
# [Step 2820/18000] Train Loss (EMA): 0.3012 | LR: 1.75e-04
# [Step 2840/18000] Train Loss (EMA): 0.2930 | LR: 1.75e-04
# [Step 2860/18000] Train Loss (EMA): 0.3065 | LR: 1.74e-04
# [Step 2880/18000] Train Loss (EMA): 0.3185 | LR: 1.74e-04
# [Step 2900/18000] Train Loss (EMA): 0.2949 | LR: 1.74e-04
# [Step 2920/18000] Train Loss (EMA): 0.3025 | LR: 1.73e-04
# [Step 2940/18000] Train Loss (EMA): 0.3151 | LR: 1.73e-04
# [Step 2960/18000] Train Loss (EMA): 0.3133 | LR: 1.72e-04
# [Step 2980/18000] Train Loss (EMA): 0.3128 | LR: 1.72e-04
# [Step 3000/18000] Train Loss (EMA): 0.3092 | LR: 1.72e-04
#
# --- Full Evaluation at Step 3000 ---
# [Val-Step-3000] loss=0.2502 | acc=0.9068 | f1=0.9059
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [Step 3020/18000] Train Loss (EMA): 0.3147 | LR: 1.71e-04
# [Step 3040/18000] Train Loss (EMA): 0.2995 | LR: 1.71e-04
# [Step 3060/18000] Train Loss (EMA): 0.2713 | LR: 1.70e-04
# [Step 3080/18000] Train Loss (EMA): 0.2896 | LR: 1.70e-04
# [Step 3100/18000] Train Loss (EMA): 0.2846 | LR: 1.69e-04
# [Step 3120/18000] Train Loss (EMA): 0.3171 | LR: 1.69e-04
# [Step 3140/18000] Train Loss (EMA): 0.3042 | LR: 1.68e-04
# [Step 3160/18000] Train Loss (EMA): 0.2963 | LR: 1.68e-04
# [Step 3180/18000] Train Loss (EMA): 0.3154 | LR: 1.68e-04
# [Step 3200/18000] Train Loss (EMA): 0.3113 | LR: 1.67e-04
# [Step 3220/18000] Train Loss (EMA): 0.3123 | LR: 1.67e-04
# [Step 3240/18000] Train Loss (EMA): 0.3019 | LR: 1.66e-04
# [Step 3260/18000] Train Loss (EMA): 0.3046 | LR: 1.66e-04
# [Step 3280/18000] Train Loss (EMA): 0.3102 | LR: 1.65e-04
# [Step 3300/18000] Train Loss (EMA): 0.3070 | LR: 1.65e-04
#
# --- Full Evaluation at Step 3300 ---
# [Val-Step-3300] loss=0.2386 | acc=0.9125 | f1=0.9121
# GPU 0: allocated=3.19 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 3300 with val_acc=0.9125
#
# [Step 3320/18000] Train Loss (EMA): 0.2989 | LR: 1.64e-04
# [Step 3340/18000] Train Loss (EMA): 0.2844 | LR: 1.64e-04
# [Step 3360/18000] Train Loss (EMA): 0.2858 | LR: 1.63e-04
# [Step 3380/18000] Train Loss (EMA): 0.2897 | LR: 1.63e-04
# [Step 3400/18000] Train Loss (EMA): 0.2880 | LR: 1.63e-04
# [Step 3420/18000] Train Loss (EMA): 0.2933 | LR: 1.62e-04
# [Step 3440/18000] Train Loss (EMA): 0.2837 | LR: 1.62e-04
# [Step 3460/18000] Train Loss (EMA): 0.2726 | LR: 1.61e-04
# [Step 3480/18000] Train Loss (EMA): 0.3103 | LR: 1.61e-04
# [Step 3500/18000] Train Loss (EMA): 0.3055 | LR: 1.60e-04
# [Step 3520/18000] Train Loss (EMA): 0.2914 | LR: 1.60e-04
# [Step 3540/18000] Train Loss (EMA): 0.2983 | LR: 1.59e-04
# [Step 3560/18000] Train Loss (EMA): 0.2957 | LR: 1.59e-04
# [Step 3580/18000] Train Loss (EMA): 0.2731 | LR: 1.58e-04
# [Step 3600/18000] Train Loss (EMA): 0.3067 | LR: 1.58e-04
#
# --- Full Evaluation at Step 3600 ---
# [Val-Step-3600] loss=0.2484 | acc=0.9126 | f1=0.9129
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 3600 with val_acc=0.9126
#
# [Step 3620/18000] Train Loss (EMA): 0.2835 | LR: 1.57e-04
# [Step 3640/18000] Train Loss (EMA): 0.2925 | LR: 1.57e-04
# [Step 3660/18000] Train Loss (EMA): 0.3048 | LR: 1.56e-04
# [Step 3680/18000] Train Loss (EMA): 0.2886 | LR: 1.56e-04
# [Step 3700/18000] Train Loss (EMA): 0.3006 | LR: 1.55e-04
# [Step 3720/18000] Train Loss (EMA): 0.2715 | LR: 1.55e-04
# [Step 3740/18000] Train Loss (EMA): 0.2890 | LR: 1.54e-04
# [Step 3760/18000] Train Loss (EMA): 0.2992 | LR: 1.54e-04
# [Step 3780/18000] Train Loss (EMA): 0.2683 | LR: 1.53e-04
# [Step 3800/18000] Train Loss (EMA): 0.2816 | LR: 1.53e-04
# [Step 3820/18000] Train Loss (EMA): 0.2776 | LR: 1.52e-04
# [Step 3840/18000] Train Loss (EMA): 0.2574 | LR: 1.52e-04
# [Step 3860/18000] Train Loss (EMA): 0.2853 | LR: 1.51e-04
# [Step 3880/18000] Train Loss (EMA): 0.2962 | LR: 1.51e-04
# [Step 3900/18000] Train Loss (EMA): 0.3004 | LR: 1.50e-04
#
# --- Full Evaluation at Step 3900 ---
# [Val-Step-3900] loss=0.2495 | acc=0.9144 | f1=0.9148
# GPU 0: allocated=3.19 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 3900 with val_acc=0.9144
#
# [Step 3920/18000] Train Loss (EMA): 0.3021 | LR: 1.49e-04
# [Step 3940/18000] Train Loss (EMA): 0.2761 | LR: 1.49e-04
# [Step 3960/18000] Train Loss (EMA): 0.2792 | LR: 1.48e-04
# [Step 3980/18000] Train Loss (EMA): 0.2741 | LR: 1.48e-04
# [Step 4000/18000] Train Loss (EMA): 0.2723 | LR: 1.47e-04
# [Step 4020/18000] Train Loss (EMA): 0.2672 | LR: 1.47e-04
# [Step 4040/18000] Train Loss (EMA): 0.2839 | LR: 1.46e-04
# [Step 4060/18000] Train Loss (EMA): 0.2954 | LR: 1.46e-04
# [Step 4080/18000] Train Loss (EMA): 0.2921 | LR: 1.45e-04
# [Step 4100/18000] Train Loss (EMA): 0.2964 | LR: 1.45e-04
# [Step 4120/18000] Train Loss (EMA): 0.3006 | LR: 1.44e-04
# [Step 4140/18000] Train Loss (EMA): 0.2956 | LR: 1.44e-04
# [Step 4160/18000] Train Loss (EMA): 0.3039 | LR: 1.43e-04
# [Step 4180/18000] Train Loss (EMA): 0.2784 | LR: 1.42e-04
# [Step 4200/18000] Train Loss (EMA): 0.2722 | LR: 1.42e-04
#
# --- Full Evaluation at Step 4200 ---
# [Val-Step-4200] loss=0.2346 | acc=0.9141 | f1=0.9140
# GPU 0: allocated=3.21 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [Step 4220/18000] Train Loss (EMA): 0.2797 | LR: 1.41e-04
# [Step 4240/18000] Train Loss (EMA): 0.2689 | LR: 1.41e-04
# [Step 4260/18000] Train Loss (EMA): 0.2640 | LR: 1.40e-04
# [Step 4280/18000] Train Loss (EMA): 0.2722 | LR: 1.40e-04
# [Step 4300/18000] Train Loss (EMA): 0.2512 | LR: 1.39e-04
# [Step 4320/18000] Train Loss (EMA): 0.2649 | LR: 1.39e-04
# [Step 4340/18000] Train Loss (EMA): 0.2473 | LR: 1.38e-04
# [Step 4360/18000] Train Loss (EMA): 0.2586 | LR: 1.37e-04
# [Step 4380/18000] Train Loss (EMA): 0.2480 | LR: 1.37e-04
# [Step 4400/18000] Train Loss (EMA): 0.2367 | LR: 1.36e-04
# [Step 4420/18000] Train Loss (EMA): 0.2309 | LR: 1.36e-04
# [Step 4440/18000] Train Loss (EMA): 0.2523 | LR: 1.35e-04
# [Step 4460/18000] Train Loss (EMA): 0.2476 | LR: 1.35e-04
# [Step 4480/18000] Train Loss (EMA): 0.2534 | LR: 1.34e-04
# [Step 4500/18000] Train Loss (EMA): 0.2301 | LR: 1.33e-04
#
# --- Full Evaluation at Step 4500 ---
# [Val-Step-4500] loss=0.2306 | acc=0.9169 | f1=0.9168
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 4500 with val_acc=0.9169
#
# [Step 4520/18000] Train Loss (EMA): 0.2352 | LR: 1.33e-04
# [Step 4540/18000] Train Loss (EMA): 0.2499 | LR: 1.32e-04
# [Step 4560/18000] Train Loss (EMA): 0.2616 | LR: 1.32e-04
# [Step 4580/18000] Train Loss (EMA): 0.2187 | LR: 1.31e-04
# [Step 4600/18000] Train Loss (EMA): 0.2478 | LR: 1.31e-04
# [Step 4620/18000] Train Loss (EMA): 0.2509 | LR: 1.30e-04
# [Step 4640/18000] Train Loss (EMA): 0.2393 | LR: 1.29e-04
# [Step 4660/18000] Train Loss (EMA): 0.2332 | LR: 1.29e-04
# [Step 4680/18000] Train Loss (EMA): 0.2309 | LR: 1.28e-04
# [Step 4700/18000] Train Loss (EMA): 0.2362 | LR: 1.28e-04
# [Step 4720/18000] Train Loss (EMA): 0.2176 | LR: 1.27e-04
# [Step 4740/18000] Train Loss (EMA): 0.2200 | LR: 1.27e-04
# [Step 4760/18000] Train Loss (EMA): 0.2690 | LR: 1.26e-04
# [Step 4780/18000] Train Loss (EMA): 0.2469 | LR: 1.25e-04
# [Step 4800/18000] Train Loss (EMA): 0.2371 | LR: 1.25e-04
#
# --- Full Evaluation at Step 4800 ---
# [Val-Step-4800] loss=0.2321 | acc=0.9187 | f1=0.9186
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 4800 with val_acc=0.9187
#
# [Step 4820/18000] Train Loss (EMA): 0.2349 | LR: 1.24e-04
# [Step 4840/18000] Train Loss (EMA): 0.2501 | LR: 1.24e-04
# [Step 4860/18000] Train Loss (EMA): 0.2388 | LR: 1.23e-04
# [Step 4880/18000] Train Loss (EMA): 0.2560 | LR: 1.22e-04
# [Step 4900/18000] Train Loss (EMA): 0.2511 | LR: 1.22e-04
# [Step 4920/18000] Train Loss (EMA): 0.2520 | LR: 1.21e-04
# [Step 4940/18000] Train Loss (EMA): 0.2443 | LR: 1.21e-04
# [Step 4960/18000] Train Loss (EMA): 0.2693 | LR: 1.20e-04
# [Step 4980/18000] Train Loss (EMA): 0.2509 | LR: 1.19e-04
# [Step 5000/18000] Train Loss (EMA): 0.2557 | LR: 1.19e-04
# [Step 5020/18000] Train Loss (EMA): 0.2375 | LR: 1.18e-04
# [Step 5040/18000] Train Loss (EMA): 0.2531 | LR: 1.18e-04
# [Step 5060/18000] Train Loss (EMA): 0.2718 | LR: 1.17e-04
# [Step 5080/18000] Train Loss (EMA): 0.2517 | LR: 1.16e-04
# [Step 5100/18000] Train Loss (EMA): 0.2480 | LR: 1.16e-04
#
# --- Full Evaluation at Step 5100 ---
# [Val-Step-5100] loss=0.2393 | acc=0.9153 | f1=0.9147
# GPU 0: allocated=3.21 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [Step 5120/18000] Train Loss (EMA): 0.2522 | LR: 1.15e-04
# [Step 5140/18000] Train Loss (EMA): 0.2365 | LR: 1.15e-04
# [Step 5160/18000] Train Loss (EMA): 0.2456 | LR: 1.14e-04
# [Step 5180/18000] Train Loss (EMA): 0.2436 | LR: 1.13e-04
# [Step 5200/18000] Train Loss (EMA): 0.2254 | LR: 1.13e-04
# [Step 5220/18000] Train Loss (EMA): 0.2467 | LR: 1.12e-04
# [Step 5240/18000] Train Loss (EMA): 0.2562 | LR: 1.12e-04
# [Step 5260/18000] Train Loss (EMA): 0.2476 | LR: 1.11e-04
# [Step 5280/18000] Train Loss (EMA): 0.2351 | LR: 1.10e-04
# [Step 5300/18000] Train Loss (EMA): 0.2446 | LR: 1.10e-04
# [Step 5320/18000] Train Loss (EMA): 0.2675 | LR: 1.09e-04
# [Step 5340/18000] Train Loss (EMA): 0.2577 | LR: 1.09e-04
# [Step 5360/18000] Train Loss (EMA): 0.2624 | LR: 1.08e-04
# [Step 5380/18000] Train Loss (EMA): 0.2250 | LR: 1.07e-04
# [Step 5400/18000] Train Loss (EMA): 0.2397 | LR: 1.07e-04
#
# --- Full Evaluation at Step 5400 ---
# [Val-Step-5400] loss=0.2347 | acc=0.9159 | f1=0.9157
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [Step 5420/18000] Train Loss (EMA): 0.2454 | LR: 1.06e-04
# [Step 5440/18000] Train Loss (EMA): 0.2377 | LR: 1.06e-04
# [Step 5460/18000] Train Loss (EMA): 0.2295 | LR: 1.05e-04
# [Step 5480/18000] Train Loss (EMA): 0.2474 | LR: 1.04e-04
# [Step 5500/18000] Train Loss (EMA): 0.2376 | LR: 1.04e-04
# [Step 5520/18000] Train Loss (EMA): 0.2187 | LR: 1.03e-04
# [Step 5540/18000] Train Loss (EMA): 0.2300 | LR: 1.03e-04
# [Step 5560/18000] Train Loss (EMA): 0.2624 | LR: 1.02e-04
# [Step 5580/18000] Train Loss (EMA): 0.2549 | LR: 1.01e-04
# [Step 5600/18000] Train Loss (EMA): 0.2402 | LR: 1.01e-04
# [Step 5620/18000] Train Loss (EMA): 0.2278 | LR: 1.00e-04
# [Step 5640/18000] Train Loss (EMA): 0.2531 | LR: 9.95e-05
# [Step 5660/18000] Train Loss (EMA): 0.2489 | LR: 9.89e-05
# [Step 5680/18000] Train Loss (EMA): 0.2550 | LR: 9.83e-05
# [Step 5700/18000] Train Loss (EMA): 0.2246 | LR: 9.77e-05
#
# --- Full Evaluation at Step 5700 ---
# [Val-Step-5700] loss=0.2350 | acc=0.9172 | f1=0.9175
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [Step 5720/18000] Train Loss (EMA): 0.2348 | LR: 9.71e-05
# [Step 5740/18000] Train Loss (EMA): 0.2277 | LR: 9.65e-05
# [Step 5760/18000] Train Loss (EMA): 0.2208 | LR: 9.59e-05
# [Step 5780/18000] Train Loss (EMA): 0.2550 | LR: 9.53e-05
# [Step 5800/18000] Train Loss (EMA): 0.2394 | LR: 9.47e-05
# [Step 5820/18000] Train Loss (EMA): 0.2550 | LR: 9.41e-05
# [Step 5840/18000] Train Loss (EMA): 0.2492 | LR: 9.35e-05
# [Step 5860/18000] Train Loss (EMA): 0.2459 | LR: 9.29e-05
# [Step 5880/18000] Train Loss (EMA): 0.2434 | LR: 9.23e-05
# [Step 5900/18000] Train Loss (EMA): 0.2671 | LR: 9.17e-05
# [Step 5920/18000] Train Loss (EMA): 0.2332 | LR: 9.11e-05
# [Step 5940/18000] Train Loss (EMA): 0.2427 | LR: 9.05e-05
# [Step 5960/18000] Train Loss (EMA): 0.2561 | LR: 8.98e-05
# [Step 5980/18000] Train Loss (EMA): 0.2451 | LR: 8.92e-05
# [Step 6000/18000] Train Loss (EMA): 0.2446 | LR: 8.86e-05
#
# --- Full Evaluation at Step 6000 ---
# [Val-Step-6000] loss=0.2271 | acc=0.9190 | f1=0.9186
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 6000 with val_acc=0.9190
#
# [Step 6020/18000] Train Loss (EMA): 0.2295 | LR: 8.80e-05
# [Step 6040/18000] Train Loss (EMA): 0.2482 | LR: 8.74e-05
# [Step 6060/18000] Train Loss (EMA): 0.2422 | LR: 8.68e-05
# [Step 6080/18000] Train Loss (EMA): 0.2275 | LR: 8.62e-05
# [Step 6100/18000] Train Loss (EMA): 0.2409 | LR: 8.56e-05
# [Step 6120/18000] Train Loss (EMA): 0.2469 | LR: 8.50e-05
# [Step 6140/18000] Train Loss (EMA): 0.2616 | LR: 8.44e-05
# [Step 6160/18000] Train Loss (EMA): 0.2433 | LR: 8.38e-05
# [Step 6180/18000] Train Loss (EMA): 0.2602 | LR: 8.32e-05
# [Step 6200/18000] Train Loss (EMA): 0.2489 | LR: 8.26e-05
# [Step 6220/18000] Train Loss (EMA): 0.2056 | LR: 8.20e-05
# [Step 6240/18000] Train Loss (EMA): 0.2523 | LR: 8.14e-05
# [Step 6260/18000] Train Loss (EMA): 0.2317 | LR: 8.08e-05
# [Step 6280/18000] Train Loss (EMA): 0.2180 | LR: 8.02e-05
# [Step 6300/18000] Train Loss (EMA): 0.2291 | LR: 7.97e-05
#
# --- Full Evaluation at Step 6300 ---
# [Val-Step-6300] loss=0.2288 | acc=0.9179 | f1=0.9174
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [Step 6320/18000] Train Loss (EMA): 0.2237 | LR: 7.91e-05
# [Step 6340/18000] Train Loss (EMA): 0.2541 | LR: 7.85e-05
# [Step 6360/18000] Train Loss (EMA): 0.2264 | LR: 7.79e-05
# [Step 6380/18000] Train Loss (EMA): 0.2271 | LR: 7.73e-05
# [Step 6400/18000] Train Loss (EMA): 0.2461 | LR: 7.67e-05
# [Step 6420/18000] Train Loss (EMA): 0.2427 | LR: 7.61e-05
# [Step 6440/18000] Train Loss (EMA): 0.2343 | LR: 7.55e-05
# [Step 6460/18000] Train Loss (EMA): 0.2395 | LR: 7.49e-05
# [Step 6480/18000] Train Loss (EMA): 0.2560 | LR: 7.43e-05
# [Step 6500/18000] Train Loss (EMA): 0.2297 | LR: 7.38e-05
# [Step 6520/18000] Train Loss (EMA): 0.2616 | LR: 7.32e-05
# [Step 6540/18000] Train Loss (EMA): 0.2407 | LR: 7.26e-05
# [Step 6560/18000] Train Loss (EMA): 0.2732 | LR: 7.20e-05
# [Step 6580/18000] Train Loss (EMA): 0.2603 | LR: 7.14e-05
# [Step 6600/18000] Train Loss (EMA): 0.2427 | LR: 7.08e-05
#
# --- Full Evaluation at Step 6600 ---
# [Val-Step-6600] loss=0.2223 | acc=0.9217 | f1=0.9215
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [save] Intermediate model saved at step 6600 with val_acc=0.9217
#
# [Step 6620/18000] Train Loss (EMA): 0.2362 | LR: 7.03e-05
# [Step 6640/18000] Train Loss (EMA): 0.2540 | LR: 6.97e-05
# [Step 6660/18000] Train Loss (EMA): 0.2154 | LR: 6.91e-05
# [Step 6680/18000] Train Loss (EMA): 0.2532 | LR: 6.85e-05
# [Step 6700/18000] Train Loss (EMA): 0.2607 | LR: 6.79e-05
# [Step 6720/18000] Train Loss (EMA): 0.2322 | LR: 6.74e-05
# [Step 6740/18000] Train Loss (EMA): 0.2312 | LR: 6.68e-05
# [Step 6760/18000] Train Loss (EMA): 0.2177 | LR: 6.62e-05
# [Step 6780/18000] Train Loss (EMA): 0.2194 | LR: 6.57e-05
# [Step 6800/18000] Train Loss (EMA): 0.2243 | LR: 6.51e-05
# [Step 6820/18000] Train Loss (EMA): 0.2330 | LR: 6.45e-05
# [Step 6840/18000] Train Loss (EMA): 0.2348 | LR: 6.40e-05
# [Step 6860/18000] Train Loss (EMA): 0.2570 | LR: 6.34e-05
# [Step 6880/18000] Train Loss (EMA): 0.2400 | LR: 6.28e-05
# [Step 6900/18000] Train Loss (EMA): 0.2533 | LR: 6.23e-05
#
# --- Full Evaluation at Step 6900 ---
# [Val-Step-6900] loss=0.2329 | acc=0.9170 | f1=0.9171
# GPU 0: allocated=3.20 GB | reserved=13.27 GB
# GPU 1: allocated=0.00 GB | reserved=0.00 GB
# [Step 6920/18000] Train Loss (EMA): 0.2323 | LR: 6.17e-05
# [Step 6940/18000] Train Loss (EMA): 0.2359 | LR: 6.11e-05
#
# *** GRACEFUL TIMEOUT: Time limit reached. Stopping training at step 6942 to save weights. ***
#
#
# Saving the final (last) step model...
#
# Generating training curves...
#
# === Evaluating LAST Step Model ===
# [Test-Last] loss=0.2361 | acc=0.9178 | f1=0.9176
#
# === Restoring and Evaluating BEST Step Model ===
# [Test-Best] loss=0.2350 | acc=0.9152 | f1=0.9149
#
# Extracting 'Hard Cases' for Qualitative Error Analysis...
# Saved 808 Last Model failures.
# Saved 833 Best Model failures.
# Saved 705 overlapping 'Hard Cases'.
#
# Training Complete. All files saved to: /kaggle/working/qwen25_snli_ddp_output

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image, display

OUTPUT_DIR = "/kaggle/working/qwen25_snli_ddp_output"

print("==================================================")
print(" 1. TRAINING & VALIDATION CURVES (BY STEP)")
print("==================================================")
display(Image(filename=f"{OUTPUT_DIR}/training_curves.png"))

print("\n==================================================")
print(" 2. CONFUSION MATRICES (LAST VS BEST MODEL)")
print("==================================================")
display(Image(filename=f"{OUTPUT_DIR}/confusion_matrices_comparison.png"))

print("\n==================================================")
print(" 3. ERROR DISTRIBUTION ANALYSIS (BAR CHARTS)")
print("==================================================")
try:
    # Load the failure CSVs generated by your training script
    best_df = pd.read_csv(f"{OUTPUT_DIR}/failures_best_model.csv")
    last_df = pd.read_csv(f"{OUTPUT_DIR}/failures_last_model.csv")

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    label_order = ["entailment", "neutral", "contradiction"]
    
    # Plot Best Model Errors (Updated for Seaborn v0.14.0 API)
    sns.countplot(
        data=best_df, 
        x="True_Label", 
        hue="True_Label", 
        order=label_order, 
        palette="Reds_r", 
        ax=axes[0], 
        legend=False
    )
    axes[0].set_title("BEST Model: Misclassifications by True Label", fontweight="bold")
    axes[0].set_ylabel("Number of Errors")
    axes[0].set_xlabel("True Label (Ground Truth)")
    axes[0].grid(axis='y', alpha=0.3)

    # Plot Last Model Errors (Updated for Seaborn v0.14.0 API)
    sns.countplot(
        data=last_df, 
        x="True_Label", 
        hue="True_Label", 
        order=label_order, 
        palette="Oranges_r", 
        ax=axes[1], 
        legend=False
    )
    axes[1].set_title("LAST Model: Misclassifications by True Label", fontweight="bold")
    axes[1].set_ylabel("Number of Errors")
    axes[1].set_xlabel("True Label (Ground Truth)")
    axes[1].grid(axis='y', alpha=0.3)

    plt.tight_layout()
    plt.show()
    
except FileNotFoundError:
    print("Failure CSVs not found. Make sure the training script successfully exported the hard cases.")

print("\n==================================================")
print(" 4. DETAILED METRICS LOG")
print("==================================================")
try:
    with open(f"{OUTPUT_DIR}/metrics_log.txt", "r") as f:
        lines = f.readlines()
        print("".join(lines[-25:]))
except FileNotFoundError:
    print("Metrics log file not found.")
# Out:
# ==================================================
#  1. TRAINING & VALIDATION CURVES (BY STEP)
# ==================================================
# ==================================================
#  2. CONFUSION MATRICES (LAST VS BEST MODEL)
# ==================================================
# ==================================================
#  3. ERROR DISTRIBUTION ANALYSIS (BAR CHARTS)
# ==================================================
# ==================================================
#  4. DETAILED METRICS LOG
# ==================================================
#
#
# === FINAL TEST EVALUATION ===
# --- LAST MODEL REPORT ---
#                precision    recall  f1-score   support
#
#    entailment       0.93      0.92      0.93      3368
#       neutral       0.88      0.89      0.88      3219
# contradiction       0.94      0.94      0.94      3237
#
#      accuracy                           0.92      9824
#     macro avg       0.92      0.92      0.92      9824
#  weighted avg       0.92      0.92      0.92      9824
#
# --- BEST MODEL REPORT ---
#                precision    recall  f1-score   support
#
#    entailment       0.93      0.92      0.93      3368
#       neutral       0.89      0.87      0.88      3219
# contradiction       0.93      0.95      0.94      3237
#
#      accuracy                           0.92      9824
#     macro avg       0.91      0.92      0.91      9824
#  weighted avg       0.92      0.92      0.92      9824
